# %% [markdown]
# # Aula introdutória de Python
# ## Variáveis

# %%
nome = input("Digite seu nome: ")
idade = 30
altura = 1.75

print("Seu nome é",nome,"sua idade é",idade,"sua altura é",altura)
# Out:
# Digite seu nome: Maria
# Seu nome é Maria sua idade é 30 sua altura é 1.75

# %% [markdown]
# ## Operadores aritméticos

# %%
print(5+5)
print(5-5)
print(5*5)
print(5/5)
# Out:
# 10
# 0
# 25
# 1.0
